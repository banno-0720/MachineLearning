# %%
# %pip install numpy pandas-profiling matplotlib plotly seaborn --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install opendatasets --upgrade --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import matplotlib
import opendatasets as od
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (10, 6)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
od.download('https://www.kaggle.com/c/rossmann-store-sales')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 od.download('https://www.kaggle.com/c/rossmann-store-sales')
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\opendatasets\__init__.py:13, in download(dataset_id_or_url, data_dir, force, dry_run, **kwargs)
#      10 def download(dataset_id_or_url, data_dir='.', force=False, dry_run=False, **kwargs):
#      11     # Check for a Kaggle dataset URL
#      12     if is_kaggle_url(dataset_id_or_url):
# ---> 13         return download_kaggle_dataset(dataset_id_or_url, data_dir=data_dir, force=force, dry_run=dry_run)
#      15     # Check for Google Drive URL
#      16     if is_google_drive_url(dataset_id_or_url):
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\opendatasets\utils\kaggle_api.py:53, in download_kaggle_dataset(dataset_url, data_dir, force, dry_run)
#      51 api.authenticate()
#      52 if dataset_id.split('/')[0] == 'competitions' or dataset_id.split('/')[0] == 'c':
# ---> 53     api.competition_download_files(
#      54         id,
#      55         target_dir,
#      56         force=force,
#      57         quiet=False)
#      58     zip_fname = target_dir + '/' + id + '.zip'
#      59     extract_archive(zip_fname, target_dir)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api\kaggle_api_extended.py:987, in KaggleApi.competition_download_files(self, competition, path, force, quiet)
#     983 else:
#     984     effective_path = path
#     986 response = self.process_response(
# --> 987     self.competitions_data_download_files_with_http_info(
#     988         id=competition, _preload_content=False))
#     989 url = response.retries.history[0].redirect_location.split('?')[0]
#     990 outfile = os.path.join(effective_path,
#     991                        competition + '.' + url.split('.')[-1])
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api\kaggle_api.py:384, in KaggleApi.competitions_data_download_files_with_http_info(self, id, **kwargs)
#     381 # Authentication setting
#     382 auth_settings = ['basicAuth']  # noqa: E501
# --> 384 return self.api_client.call_api(
#     385     '/competitions/data/download-all/{id}', 'GET',
#     386     path_params,
#     387     query_params,
#     388     header_params,
#     389     body=body_params,
#     390     post_params=form_params,
#     391     files=local_var_files,
#     392     response_type='Result',  # noqa: E501
#     393     auth_settings=auth_settings,
#     394     async_req=params.get('async_req'),
#     395     _return_http_data_only=params.get('_return_http_data_only'),
#     396     _preload_content=params.get('_preload_content', True),
#     397     _request_timeout=params.get('_request_timeout'),
#     398     collection_formats=collection_formats)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api_client.py:313, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     276 """Makes the HTTP request (synchronous) and returns deserialized data.
#     277
#     278 To make an async request, set the async_req parameter.
#    (...)
#     310     then the method will return the response directly.
#     311 """
#     312 if not async_req:
# --> 313     return self.__call_api(resource_path, method,
#     314                            path_params, query_params, header_params,
#     315                            body, post_params, files,
#     316                            response_type, auth_settings,
#     317                            _return_http_data_only, collection_formats,
#     318                            _preload_content, _request_timeout)
#     319 else:
#     320     thread = self.pool.apply_async(self.__call_api, (resource_path,
#     321                                    method, path_params, query_params,
#     322                                    header_params, body,
#    (...)
#     326                                    collection_formats,
#     327                                    _preload_content, _request_timeout))
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api_client.py:145, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout)
#     142 url = self.configuration.host + resource_path
#     144 # perform request and return response
# --> 145 response_data = self.request(
#     146     method, url, query_params=query_params, headers=header_params,
#     147     post_params=post_params, body=body,
#     148     _preload_content=_preload_content,
#     149     _request_timeout=_request_timeout)
#     151 self.last_response = response_data
#     153 return_data = response_data
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\api_client.py:335, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     333 """Makes the HTTP request using RESTClient."""
#     334 if method == "GET":
# --> 335     return self.rest_client.GET(url,
#     336                                 query_params=query_params,
#     337                                 _preload_content=_preload_content,
#     338                                 _request_timeout=_request_timeout,
#     339                                 headers=headers)
#     340 elif method == "HEAD":
#     341     return self.rest_client.HEAD(url,
#     342                                  query_params=query_params,
#     343                                  _preload_content=_preload_content,
#     344                                  _request_timeout=_request_timeout,
#     345                                  headers=headers)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\rest.py:231, in RESTClientObject.GET(self, url, headers, query_params, _preload_content, _request_timeout)
#     229 def GET(self, url, headers=None, query_params=None, _preload_content=True,
#     230         _request_timeout=None):
# --> 231     return self.request("GET", url,
#     232                         headers=headers,
#     233                         _preload_content=_preload_content,
#     234                         _request_timeout=_request_timeout,
#     235                         query_params=query_params)
#
# File c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\kaggle\rest.py:225, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     222     logger.debug("response body: %s", r.data)
#     224 if not 200 <= r.status <= 299:
# --> 225     raise ApiException(http_resp=r)
#     227 return r
#
# ApiException: (403)
# Reason: Forbidden
# HTTP response headers: HTTPHeaderDict({'Content-Type': 'application/json', 'Date': 'Sat, 03 Aug 2024 18:29:26 GMT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Origin': '*', 'Set-Cookie': 'ka_sessionid=c98b8ba142e5393ff5826a6d47befeaa; max-age=2626560; path=/, .AspNetCore.Mvc.CookieTempDataProvider=CfDJ8Li1e-GA90hNldzIP3u2GqAYhhB0yuXnQqn005sfgenThp2VhJNmYkmC-G8oZMwrdocaF5lV49RDQc1Z5EGynjaFisin3X-DPdhWQSK221khu6o3K9vXLLC0L21rjUBBS6F2mLdAiw54lptPyRSyvOtUvMVlfYAfTgX9ifJ2FiyOCxIowdzQD5LqijRcvdQmb9UpgDMqT3GJ3T-aXfHYTke4amVsx7svzJ3Z9QxMDJXHAjPXDfOw-OjULPXLWkJ0v3Ui_kR9hHzjDQ; path=/; samesite=lax; httponly, GCLB=COCE47Ge2MuMNhAD; path=/; HttpOnly', 'Vary': 'Accept-Encoding', 'X-Kaggle-MillisecondsElapsed': '17', 'X-Kaggle-RequestId': '0c7de06b29aec0dc57eb98895fa05203', 'X-Kaggle-ApiVersion': '1.6.17', 'X-Kaggle-HubVersion': '0.2.9', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=63072000; includeSubDomains; preload', 'Content-Security-Policy': "object-src 'none'; script-src 'nonce-TdYZeUzS9WfFqmOPkZ7XEg==' 'report-sample' 'unsafe-inline' 'unsafe-eval' 'strict-dynamic' https: http:; base-uri 'none'; report-uri https://csp.withgoogle.com/csp/kaggle/20201130; frame-src 'self' https://www.kaggleusercontent.com https://www.youtube.com/embed/ https://polygraph-cool.github.io https://www.google.com/recaptcha/ https://www.docdroid.com https://www.docdroid.net https://kaggle-static.storage.googleapis.com https://kkb-production.jupyter-proxy.kaggle.net https://kkb-production.firebaseapp.com https://kaggle-metastore.firebaseapp.com https://apis.google.com https://content-sheets.googleapis.com/ https://accounts.google.com/ https://storage.googleapis.com https://docs.google.com https://drive.google.com https://calendar.google.com/ ;", 'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'strict-origin-when-cross-origin', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000', 'Transfer-Encoding': 'chunked'})
# HTTP response body: b'{"code":403,"message":"You must accept this competition\\u0027s rules before you\\u0027ll be able to download files."}'

# %%
os.listdir('rossmann-store-sales')
